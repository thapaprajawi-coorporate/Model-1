# %%
#this is for calculating the balloon payment
import numpy_financial as npf
P = float(input("The total amount of money that you loaned out: "))
initial_principal = P
R = float(input("The interest rate on said loan in decimal:"))
T = int(input("The term of the loan in months:"))
CFDA = []
Discounted_CFDA = []
New_CFDA = []
New_CFDA.append(-P)
mr = R / 12                                            
for i in range(T):
    cash_flow = float(input( f"Enter the Cash FLow Available for Debt Services for month {i+1}:"))
    discounted_cash_flow = ( cash_flow / ( 1 + mr ) ** ( i + 1 ))
    CFDA.append(cash_flow)
    New_CFDA.append(cash_flow)
    Discounted_CFDA.append(discounted_cash_flow)
    
print("Your CFDAS for the term of the loan is:",CFDA)
print("Your DCFDAS for the term of the loan is:",Discounted_CFDA)

i = 0
interest = []
while i < T:
    interest_current_month = P * mr
    interest.append(interest_current_month)
    if CFDA[i] - interest_current_month >= P:
        principal_paid_current = P
        ending_balance = 0
        print(f"Loan has been paid off early in month {i+1}")
    else:
        principal_paid_current = CFDA[i] - interest_current_month
        ending_balance = P - principal_paid_current
    P = ending_balance
    print(f"Principal paid for month {i + 1}: {principal_paid_current}")
    i = i + 1
balloon = ending_balance
print(" Final balloon payment:", balloon) 

#calculating the ICR: Interest Coverage Ratio

total_interest = sum(interest)
earning_before_tax_interest = sum(CFDA) 

ICR = earning_before_tax_interest/total_interest

print(f"The Interest Coverage ratio is:{ICR}")

if ICR < 3:
    print(f"Warning: The proposed loan puts the business's ICR is at: {ICR}. The business may struggle to refinance the balloon payment under current cashflow conditions")
else:
    print(f"Based on current cash flows, the business maintains a healthy ICR of :{ICR}. This indicates a strong likelihood of qualifying for refinancing when the balloon payment is due")

# calculating simple pay back time

total = 0
paid_off = False 
for i in range(T):
    total = total + CFDA [ i ]
    if total >= initial_principal:
        print(f"The simple payback period is:{i+1}")
        paid_off = True 
        break 
        
if paid_off == False :
    print("The loan principal is not fully recovered within the term")

# calculating discounted pay back time 

discounted_total = 0
paid_off = False 

for i in range(T):
    discounted_total = discounted_total + Discounted_CFDA[i]
    if discounted_total >= initial_principal:
        print(f"The discounted payback period is:{i+1}")
        paid_off = True 
        break 
        
if paid_off == False :
    print("The loan principal is not fully recovered within the term")

#calculating net present value 

NPV = sum(Discounted_CFDA) - initial_principal

if NPV >=0 :
    print(" The bank has approved the provision of a loan to your business")

else:
    print("We cannot provide you the loan")

#calcualting IRR :

IRR = npf.irr(New_CFDA)

print(f"The Internal Rate of Return (IRR) is: {IRR})
# Out:
# The total amount of money that you loaned out:  60000000
# The interest rate on said loan in decimal: 0.15
# The term of the loan in months: 3
# Enter the Cash FLow Available for Debt Services for month 1: 200000
# Enter the Cash FLow Available for Debt Services for month 2: 300000
# Enter the Cash FLow Available for Debt Services for month 3: 400000
# Your CFDAS for the term of the loan is: [200000.0, 300000.0, 400000.0]
# Your DCFDAS for the term of the loan is: [197530.86419753087, 292638.31732967537, 385367.331462947]
# Principal paid for month 1: -549999.9999999999
# Principal paid for month 2: -456874.9999999999
# Principal paid for month 3: -362585.9374999999
#  Final balloon payment: 61369460.9375
# The Interest Coverage ratio is:0.39656994536835916
# Warning: The proposed loan puts the business's ICR is at: 0.39656994536835916. The business may struggle to refinance the balloon payment under current cashflow conditions
# The loan principal is not fully recovered within the term
# The loan principal is not fully recovered within the term
# We cannot provide you the loan
